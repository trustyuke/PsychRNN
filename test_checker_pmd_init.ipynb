# %%
import tensorflow as tf
from psychrnn.backend.models.basic import Basic
from psychrnn.backend.gain.basic2 import Basic2
from psychrnn.backend.gain.loss import rt_mask_mse_06, rt_mask_mse_07, rt_mask_mse_08
from psychrnn.tasks.checkerPmdInit import Checkerboard2AFC

from tqdm import tqdm
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Generate a batch of trials

# %%
experiment = 'interactive'
name = 'basic'
dt = 10
tau = 50
T = 5000
N_batch = 50
N_rec = 100

task = Checkerboard2AFC(dt=dt, tau=tau, T=T, N_batch=N_batch, noise = 0.75, wait = [0,0.5])

# %%
params = task.get_task_params()
params
# Out:
# {'N_batch': 50,
#  'N_in': 2,
#  'N_out': 2,
#  'dt': 10,
#  'tau': 50,
#  'T': 5000,
#  'alpha': 0.2,
#  'N_steps': 500,
#  'coherence': [0, 1],
#  'noise': 0.75,
#  'target_onset': [250, 500],
#  'checker_onset': [500, 1000],
#  'accumulation_mask': 300,
#  'decision_threshold': 0.7,
#  'post_decision_baseline': 0.2,
#  'wait': [0, 0.5],
#  'hi': 1,
#  'lo': 0}

# %%
[x, y, mask, allParams] = task.get_trial_batch()

trialNum = 5
# x[1]: left tartet evidence
# x[2]: right target evidence
trialIn = x[trialNum,:,:]
trialOut = y[trialNum,:,:]
trialMask = mask[trialNum,:,:]
time = np.linspace(0, task.T, int(task.T/task.dt))
# plot input to the model
plt.figure()
plt.plot(time, trialIn[:,0], label = 'left')
plt.plot(time, trialIn[:,1], label = 'right')
plt.legend()

# plot output to the model
plt.figure()
plt.plot(time, trialOut[:,0], label = 'left')
plt.plot(time, trialOut[:,1], label = 'right')
plt.legend()

print(allParams[trialNum])
# Out:
# {'coherence': 0.1704876115359727, 'noise': 0.75, 'accumulation_mask': 300, 'target_onset': 358, 'checker_onset': 594, 'init_y': array([0.32996808, 0.22100073])}

# %% [markdown]
# # Set network parameters

# %%
network_params = task.get_task_params()
network_params['name'] = name
network_params['N_rec'] = N_rec
network_params['rec_noise'] = 0.5

network_params["transfer_function"] = tf.nn.relu
network_params["output_transfer_function"] = tf.nn.sigmoid

network_params["loss_function"] = "rt_mask_mse"
network_params["rt_mask_mse"] = rt_mask_mse_07

# %%
try:
    model.destruct()
except:
    pass

model = Basic2(network_params)

# %% [markdown]
# # Set Training params and train

# %%
trials = 50000
train_params = {}
train_params['save_weights_path'] =  './init' #"./weights/checkerPmdBasic2InputNoise0.75"
train_params['training_iters'] = trials
train_params['learning_rate'] = .001
train_params['loss_epoch'] = 10
train_params['save_training_weights_epoch'] = 1000 / N_batch
train_params['training_weights_path'] = None

# %%
losses, initialTime, trainTime = model.train(task, train_params)
loss_name =  './init.txt' #"./losses/checkerPmdBasic2InputNoise0.75.txt"
print("Save losses to " + loss_name)
with open(loss_name, 'w') as f:
    for item in losses:
        f.write("%s\n" % item)
# Out:
# WARNING:tensorflow:From D:\BU\ChandLab\PsychRNN\psychrnn\backend\gain\basic2.py:132: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\BU\ChandLab\PsychRNN\psychrnn\backend\gain\basic2.py:132: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Iter 500, Minibatch Loss= 0.163094
# Iter 1000, Minibatch Loss= 0.097367
# Iter 1500, Minibatch Loss= 0.084206
# Iter 2000, Minibatch Loss= 0.099634
# Iter 2500, Minibatch Loss= 0.071832
# Iter 3000, Minibatch Loss= 0.072011
# Iter 3500, Minibatch Loss= 0.034496
# Iter 4000, Minibatch Loss= 0.036967
# Iter 4500, Minibatch Loss= 0.033391
# Iter 5000, Minibatch Loss= 0.030973
# Iter 5500, Minibatch Loss= 0.034252
# Iter 6000, Minibatch Loss= 0.034766
# Iter 6500, Minibatch Loss= 0.034035
# Iter 7000, Minibatch Loss= 0.028427
# Iter 7500, Minibatch Loss= 0.029338
# Iter 8000, Minibatch Loss= 0.026403
# Iter 8500, Minibatch Loss= 0.031683
# Iter 9000, Minibatch Loss= 0.022555
# Iter 9500, Minibatch Loss= 0.023219
# Iter 10000, Minibatch Loss= 0.027327
# Iter 10500, Minibatch Loss= 0.025843
# Iter 11000, Minibatch Loss= 0.026619
# Iter 11500, Minibatch Loss= 0.025739
# Iter 12000, Minibatch Loss= 0.022094
# Iter 12500, Minibatch Loss= 0.025599
# Iter 13000, Minibatch Loss= 0.021759
# Iter 13500, Minibatch Loss= 0.019331
# Iter 14000, Minibatch Loss= 0.020718
# Iter 14500, Minibatch Loss= 0.022949
# Iter 15000, Minibatch Loss= 0.020480
# Iter 15500, Minibatch Loss= 0.024908
# Iter 16000, Minibatch Loss= 0.022702
# Iter 16500, Minibatch Loss= 0.020659
# Iter 17000, Minibatch Loss= 0.021045
# Iter 17500, Minibatch Loss= 0.023939
# Iter 18000, Minibatch Loss= 0.019083
# Iter 18500, Minibatch Loss= 0.021124
# Iter 19000, Minibatch Loss= 0.020006
# Iter 19500, Minibatch Loss= 0.020438
# Iter 20000, Minibatch Loss= 0.018289
# Iter 20500, Minibatch Loss= 0.018069
# Iter 21000, Minibatch Loss= 0.017617
# Iter 21500, Minibatch Loss= 0.019517
# Iter 22000, Minibatch Loss= 0.020048
# Iter 22500, Minibatch Loss= 0.020546
# Iter 23000, Minibatch Loss= 0.016306
# Iter 23500, Minibatch Loss= 0.016298
# Iter 24000, Minibatch Loss= 0.019171
# Iter 24500, Minibatch Loss= 0.014506
# Iter 25000, Minibatch Loss= 0.015251
# Iter 25500, Minibatch Loss= 0.021165
# Iter 26000, Minibatch Loss= 0.015143
# Iter 26500, Minibatch Loss= 0.018759
# Iter 27000, Minibatch Loss= 0.015058
# Iter 27500, Minibatch Loss= 0.020552
# Iter 28000, Minibatch Loss= 0.022997
# Iter 28500, Minibatch Loss= 0.015949
# Iter 29000, Minibatch Loss= 0.014298
# Iter 29500, Minibatch Loss= 0.016313
# Iter 30000, Minibatch Loss= 0.020667
# Iter 30500, Minibatch Loss= 0.015146
# Iter 31000, Minibatch Loss= 0.018980
# Iter 31500, Minibatch Loss= 0.017248
# Iter 32000, Minibatch Loss= 0.013848
# Iter 32500, Minibatch Loss= 0.016568
# Iter 33000, Minibatch Loss= 0.017067
# Iter 33500, Minibatch Loss= 0.017499
# Iter 34000, Minibatch Loss= 0.012503
# Iter 34500, Minibatch Loss= 0.014501
# Iter 35000, Minibatch Loss= 0.016986
# Iter 35500, Minibatch Loss= 0.016494
# Iter 36000, Minibatch Loss= 0.012620
# Iter 36500, Minibatch Loss= 0.015229
# Iter 37000, Minibatch Loss= 0.013238
# Iter 37500, Minibatch Loss= 0.015532
# Iter 38000, Minibatch Loss= 0.014051
# Iter 38500, Minibatch Loss= 0.010362
# Iter 39000, Minibatch Loss= 0.012260
# Iter 39500, Minibatch Loss= 0.017358
# Iter 40000, Minibatch Loss= 0.012035
# Iter 40500, Minibatch Loss= 0.010886
# Iter 41000, Minibatch Loss= 0.013797
# Iter 41500, Minibatch Loss= 0.012820
# Iter 42000, Minibatch Loss= 0.014289
# Iter 42500, Minibatch Loss= 0.013823
# Iter 43000, Minibatch Loss= 0.013475
# Iter 43500, Minibatch Loss= 0.011003
# Iter 44000, Minibatch Loss= 0.015223
# Iter 44500, Minibatch Loss= 0.013758
# Iter 45000, Minibatch Loss= 0.012027
# Iter 45500, Minibatch Loss= 0.015356
# Iter 46000, Minibatch Loss= 0.010950
# Iter 46500, Minibatch Loss= 0.012392
# Iter 47000, Minibatch Loss= 0.010789
# Iter 47500, Minibatch Loss= 0.010269
# Iter 48000, Minibatch Loss= 0.014110
# Iter 48500, Minibatch Loss= 0.010052
# Iter 49000, Minibatch Loss= 0.012566
# Iter 49500, Minibatch Loss= 0.010048
# Optimization finished!
# Model saved in file: ./init
# Save losses to ./init.txt

# %%
plt.plot(losses)
plt.ylabel("Loss")
plt.xlabel("Training Iteration")
plt.title("Loss During Training")
# Out:
# Text(0.5, 1.0, 'Loss During Training')

# %% [markdown]
# # Test 5000 trials

# %%
trials = 5000
batches = int(np.ceil(trials / N_batch))

rnn_state = np.zeros((trials, task.N_steps, model.N_rec))
rnn_out = np.zeros((trials, task.N_steps, model.N_out))

coherence = np.zeros(trials)
target_onset = np.zeros(trials)
checker_onset = np.zeros(trials)
decision = np.zeros(trials)
rt = np.zeros(trials)

init_y_left = np.zeros(trials)
init_y_right = np.zeros(trials)

# %%
for b in tqdm(range(batches)):
    x, y, m, params = task.get_trial_batch()
    outputs, states, inputs = model.test(x)
    
    start_index = N_batch * b
    end_index = N_batch * (b + 1)
    rnn_state[start_index:end_index] = states
    rnn_out[start_index:end_index] = outputs

    
    thr = np.where(outputs > 0.7)
    
    for i in range(N_batch):
        index = start_index + i
        
        coherence[index] = params[i]["coherence"]
        target_onset[index] = params[i]["target_onset"]
        checker_onset[index] = params[i]["checker_onset"]
        
        thr_time = thr[1][thr[0]==i][0] if sum(thr[0]==i) > 0 else outputs.shape[1]
        thr_unit = thr[2][thr[0]==i][0] if sum(thr[0]==i) > 0 else np.argmax(outputs[i, -1])
        decision[index] = thr_unit
        rt[index] = thr_time*task.dt - target_onset[index] - checker_onset[index] 
        
        init_y_left[index] = params[i]["init_y"][0] 
        init_y_right[index] = params[i]["init_y"][0]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:41<00:00,  2.42it/s]

# %%
#onsets = [p["onset_time"] for p in params]
onsets = target_onset[-N_batch:] + checker_onset[-N_batch:]
rts = rt[-N_batch:]
for i in range(10):
    plt.figure()
    plt.plot(np.arange(0, 5000, 10), inputs[i, :, 0])
    plt.plot(np.arange(0, 5000, 10), inputs[i, :, 1])

    plt.figure()
    plt.plot(np.arange(0, 5000, 10), outputs[i, :, 0])
    plt.plot(np.arange(0, 5000, 10), outputs[i, :, 1])
    
    plt.vlines(onsets[i], 0, 1)
    plt.vlines(onsets[i] + rts[i], 0, 1)
    plt.hlines(0.7, 0, 5000)

# %%
correct_side = (coherence > 0.5)
correct_side = 1 - 1*correct_side


checker_df = pd.DataFrame({'trial' : np.arange(trials),
                           # the real coherence based on left and right (positive: left evidence dominant
                           # negative: right evidence dominant)
                           'coherence' : 2*coherence - 1,
                           'coherence_bin' : np.round(2*coherence - 1, 1),
                           'correct_side' : correct_side,
                           'target_onset' : target_onset,
                           'checker_onset' : checker_onset,
                           'decision' : decision,
                           'decision_time' : rt,
                           'correct_decision' : (decision == correct_side).astype(int),
                           'init_y_left' : init_y_left,
                           'init_y_right' : init_y_right})
checker_mean = checker_df.groupby('coherence_bin').mean().reset_index()

print("Overall Accuracy: " + str(np.sum(checker_df["correct_decision"])/len(checker_df)))
print("Negative RT trials ratio: ", end = "")
print(np.sum(checker_df["decision_time"] < 0)/len(checker_df))
# Out:
# Overall Accuracy: 0.8154
# Negative RT trials ratio: 0.0

# %%
#######################
## summary result save path

resultPath = "./resultData/checkerPmdInit.csv"
checker_df.to_csv(resultPath)

# %%
plt.figure(figsize=(13, 5))
plt.subplot(1,2,1)
plt.plot(checker_mean['coherence_bin'], 1-checker_mean['decision'])
plt.scatter(checker_mean['coherence_bin'], 1-checker_mean['decision'])
plt.xlabel("left coherence")
plt.ylabel("proportion of choosing left")
plt.subplot(1,2,2)
plt.plot(checker_mean['coherence_bin'], checker_mean['decision_time'])
plt.scatter(checker_mean['coherence_bin'], checker_mean['decision_time'])

# %% [markdown]
# # RT within same coherence

# %%
idx = 1
plt.figure(figsize=(15, 8))
for i in [0.9,0.7,0.5,0.3,0.1,0]:
    a = checker_df['coherence_bin'] == i
    groupCo = checker_df.loc[a,:]
    RT = groupCo["decision_time"]
    plt.subplot(2,3,idx)
    plt.hist(RT, bins = 25)
    plt.title("Coherence: " + str(i))
    idx = idx + 1

# %% [markdown]
# # Check the activity of each recurrent unit

# %%
trial_num = 5
plt.figure()
plt.subplot(211)
_ = plt.plot(np.arange(0, T, dt), rnn_state[trial_num,:,:])
plt.xlabel("time step (10ms)")
plt.ylabel("firing rate")
plt.subplot(212)
_ = plt.plot(np.arange(0, T, dt), rnn_out[trial_num,:,0], label = "left")
_ = plt.plot(np.arange(0, T, dt), rnn_out[trial_num,:,1], label = "right")
plt.legend()

# save the firing rate of of each unit and output
# trialDat = {'state':rnn_state, 'y':rnn_out}
# np.save("./stateActivityCheckerPmdInputNoise0.25.npy",trialDat)

# %%
# transpose the data and save as .mat file for analysis on matlab
temp = np.transpose(rnn_state, (2,1,0))
from scipy.io import savemat
mdic = {'temp': temp}
savemat("temp.mat", mdic)
